# %%
# import os
# from pathlib import Path
# import wandb

# BASE_PATH = "/content/arena-capstone"

# if not os.path.exists(BASE_PATH):
#     !git clone https://github.com/arunim1/arena-capstone.git


# os.chdir(BASE_PATH)
# assert os.getcwd() == BASE_PATH


# !pip install -r requirements.txt
# os.chdir(str(Path(BASE_PATH) / "src"))
# !pip install -e .

# %%
from arena_capstone.algorithm.gcg import GCGConfig, GCG
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers import LlamaModel, LlamaConfig
import torch as t

device = t.device('cuda' if t.cuda.is_available() else 'cpu')
# model_name = "gpt2"
configuration = LlamaConfig()


# model = AutoModelForCausalLM.from_pretrained(model_name).to(device)
model = LlamaModel(configuration)

# tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
cfg = GCGConfig(
    suffix=t.randint(0, 50257, (6,), device=device),
    prefix_str="The cat",
    target_str=" is a dawg",
    batch_size=50,
    T=5000,
    k=50,
    device=device,
)

gcg = GCG(cfg=cfg, model=model)
gcg.gcg(print_between=True)
